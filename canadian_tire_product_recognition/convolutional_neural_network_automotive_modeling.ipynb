# %% [markdown]
# ## **1. CONVOLUTIONAL NEURAL NETWORK (CNN) MODEL**

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from keras.utils.np_utils import to_categorical
from tensorflow.keras.constraints import unit_norm
from tensorflow.python.keras import regularizers


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

import os
import cv2
import random
import time
import pickle

SEED = 0

def set_seeds(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    np.random.seed(seed)
  
def set_global_determinism(seed=SEED):
    set_seeds(seed=seed)

    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
    
    tf.config.threading.set_inter_op_parallelism_threads(1)
    tf.config.threading.set_intra_op_parallelism_threads(1)

# Call the above function with seed value
set_global_determinism(seed=SEED)

# %%
# load Dataset

X = pickle.load(open("/content/gdrive/MyDrive/Colab Notebooks/automotive_runs/X_256.pickle", "rb"))
y = pickle.load(open("/content/gdrive/MyDrive/Colab Notebooks/automotive_runs/y_256.pickle", "rb"))
categories = pickle.load(open("/content/gdrive/MyDrive/Colab Notebooks/automotive_runs/categories.pickle", "rb"))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)
num_classes = len(categories)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255.0
X_test /= 255.0
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (17451, 256, 256, 1)
# (17451, 50)
# (7480, 256, 256, 1)
# (7480, 50)

# %%
def print_graphs(model_history):
     # summarize history for loss
    plt.plot(model_history.history['loss'], color='orange')
    plt.plot(model_history.history['val_loss'], color='blue')
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Training loss', 'Validation loss'], loc='upper left')
    plt.show()
    
    # summarize history for accuracy
    plt.plot(model_history.history['accuracy'], color='orange')
    plt.plot(model_history.history['val_accuracy'], color='blue')
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Training accuracy', 'Validation accuracy'], loc='upper left')
    plt.show()

# %% [markdown]
# ## **1.2. MODEL 1**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', activation='relu'))
cnn.add(MaxPooling2D())

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
cnn.add(MaxPooling2D())

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              268436480
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 268,539,826
# Trainable params: 268,539,826
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 546/546 [==============================] - 62s 85ms/step - loss: 2.1393 - accuracy: 0.5533 - val_loss: 0.8677 - val_accuracy: 0.8025
# Epoch 2/10
# 546/546 [==============================] - 46s 85ms/step - loss: 0.3673 - accuracy: 0.9127 - val_loss: 0.8617 - val_accuracy: 0.8309
# Epoch 3/10
# 546/546 [==============================] - 46s 85ms/step - loss: 0.0453 - accuracy: 0.9881 - val_loss: 1.0741 - val_accuracy: 0.8449
# Epoch 4/10
# 546/546 [==============================] - 46s 85ms/step - loss: 0.0353 - accuracy: 0.9917 - val_loss: 1.1471 - val_accuracy: 0.8432
# Epoch 5/10
# 546/546 [==============================] - 46s 85ms/step - loss: 0.0496 - accuracy: 0.9883 - val_loss: 1.0922 - val_accuracy: 0.8393
# Epoch 6/10
# 546/546 [==============================] - 46s 84ms/step - loss: 0.0295 - accuracy: 0.9921 - val_loss: 1.2739 - val_accuracy: 0.8449
# Epoch 7/10
# 546/546 [==============================] - 46s 84ms/step - loss: 0.0153 - accuracy: 0.9965 - val_loss: 1.3432 - val_accuracy: 0.8405
# Epoch 8/10
# 546/546 [==============================] - 46s 84ms/step - loss: 0.0353 - accuracy: 0.9919 - val_loss: 1.5776 - val_accuracy: 0.8287
# Epoch 9/10
# 546/546 [==============================] - 46s 84ms/step - loss: 0.0258 - accuracy: 0.9940 - val_loss: 1.5653 - val_accuracy: 0.8384
# Epoch 10/10
# 546/546 [==============================] - 46s 84ms/step - loss: 0.0202 - accuracy: 0.9948 - val_loss: 1.5925 - val_accuracy: 0.8366
# Time elapsed: 477.0803964138031s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.3. MODEL 2**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 268,539,826
# Trainable params: 268,539,826
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 546/546 [==============================] - 48s 88ms/step - loss: 3.2874 - accuracy: 0.2962 - val_loss: 1.4300 - val_accuracy: 0.6884
# Epoch 2/10
# 546/546 [==============================] - 48s 88ms/step - loss: 1.0154 - accuracy: 0.7684 - val_loss: 0.9705 - val_accuracy: 0.7914
# Epoch 3/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.4643 - accuracy: 0.8799 - val_loss: 0.8810 - val_accuracy: 0.8237
# Epoch 4/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.1748 - accuracy: 0.9535 - val_loss: 1.0628 - val_accuracy: 0.8246
# Epoch 5/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.1071 - accuracy: 0.9697 - val_loss: 1.1455 - val_accuracy: 0.8346
# Epoch 6/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.0770 - accuracy: 0.9787 - val_loss: 1.2621 - val_accuracy: 0.8328
# Epoch 7/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.0705 - accuracy: 0.9810 - val_loss: 1.2966 - val_accuracy: 0.8330
# Epoch 8/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.0562 - accuracy: 0.9847 - val_loss: 1.4041 - val_accuracy: 0.8294
# Epoch 9/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.0584 - accuracy: 0.9840 - val_loss: 1.4686 - val_accuracy: 0.8285
# Epoch 10/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.0640 - accuracy: 0.9836 - val_loss: 1.4277 - val_accuracy: 0.8372
# Time elapsed: 478.3611309528351s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.4. MODEL 3**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu'))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 268,539,826
# Trainable params: 268,539,826
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 546/546 [==============================] - 48s 88ms/step - loss: 4.5467 - accuracy: 0.3721 - val_loss: 1.5686 - val_accuracy: 0.7213
# Epoch 2/10
# 546/546 [==============================] - 48s 88ms/step - loss: 1.0809 - accuracy: 0.8090 - val_loss: 1.1784 - val_accuracy: 0.8013
# Epoch 3/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.5349 - accuracy: 0.9109 - val_loss: 1.2373 - val_accuracy: 0.8176
# Epoch 4/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.3275 - accuracy: 0.9520 - val_loss: 1.3259 - val_accuracy: 0.8259
# Epoch 5/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.2473 - accuracy: 0.9689 - val_loss: 1.4452 - val_accuracy: 0.8258
# Epoch 6/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1940 - accuracy: 0.9743 - val_loss: 1.4424 - val_accuracy: 0.8247
# Epoch 7/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1711 - accuracy: 0.9757 - val_loss: 1.4392 - val_accuracy: 0.8291
# Epoch 8/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1296 - accuracy: 0.9809 - val_loss: 1.3685 - val_accuracy: 0.8345
# Epoch 9/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1193 - accuracy: 0.9831 - val_loss: 1.4813 - val_accuracy: 0.8328
# Epoch 10/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.0885 - accuracy: 0.9856 - val_loss: 1.4695 - val_accuracy: 0.8287
# Time elapsed: 478.60074067115784s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.5. MODEL 4**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())


start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_7 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 268,539,826
# Trainable params: 268,539,826
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 546/546 [==============================] - 48s 88ms/step - loss: 7.0204 - accuracy: 0.2133 - val_loss: 2.1821 - val_accuracy: 0.5987
# Epoch 2/10
# 546/546 [==============================] - 48s 88ms/step - loss: 1.4528 - accuracy: 0.7270 - val_loss: 1.2836 - val_accuracy: 0.7767
# Epoch 3/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.6041 - accuracy: 0.8975 - val_loss: 1.2921 - val_accuracy: 0.8015
# Epoch 4/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.3534 - accuracy: 0.9546 - val_loss: 1.3691 - val_accuracy: 0.8112
# Epoch 5/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.2824 - accuracy: 0.9687 - val_loss: 1.5572 - val_accuracy: 0.8255
# Epoch 6/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.2441 - accuracy: 0.9750 - val_loss: 1.6288 - val_accuracy: 0.8245
# Epoch 7/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.2098 - accuracy: 0.9786 - val_loss: 1.6535 - val_accuracy: 0.8158
# Epoch 8/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1995 - accuracy: 0.9789 - val_loss: 1.6091 - val_accuracy: 0.8242
# Epoch 9/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1666 - accuracy: 0.9827 - val_loss: 1.5725 - val_accuracy: 0.8310
# Epoch 10/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1332 - accuracy: 0.9864 - val_loss: 1.5066 - val_accuracy: 0.8309
# Time elapsed: 479.4036717414856s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.6. MODEL 5**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(num_classes, activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 262144)            0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              268436480
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 268,539,826
# Trainable params: 268,539,826
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 546/546 [==============================] - 50s 88ms/step - loss: 6.7827 - accuracy: 0.2006 - val_loss: 2.1143 - val_accuracy: 0.6056
# Epoch 2/10
# 546/546 [==============================] - 48s 87ms/step - loss: 1.4859 - accuracy: 0.7235 - val_loss: 1.2726 - val_accuracy: 0.7842
# Epoch 3/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.6561 - accuracy: 0.8913 - val_loss: 1.2050 - val_accuracy: 0.8136
# Epoch 4/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.3723 - accuracy: 0.9548 - val_loss: 1.3000 - val_accuracy: 0.8219
# Epoch 5/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.2845 - accuracy: 0.9707 - val_loss: 1.3664 - val_accuracy: 0.8269
# Epoch 6/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.2345 - accuracy: 0.9770 - val_loss: 1.5523 - val_accuracy: 0.8310
# Epoch 7/10
# 546/546 [==============================] - 48s 88ms/step - loss: 0.1971 - accuracy: 0.9820 - val_loss: 1.4246 - val_accuracy: 0.8269
# Epoch 8/10
# 546/546 [==============================] - 47s 87ms/step - loss: 0.1668 - accuracy: 0.9831 - val_loss: 1.4009 - val_accuracy: 0.8301
# Epoch 9/10
# 546/546 [==============================] - 47s 87ms/step - loss: 0.1354 - accuracy: 0.9861 - val_loss: 1.4323 - val_accuracy: 0.8295
# Epoch 10/10
# 546/546 [==============================] - 47s 87ms/step - loss: 0.1178 - accuracy: 0.9881 - val_loss: 1.3691 - val_accuracy: 0.8242
# Time elapsed: 478.5404906272888s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.7. MODEL 6**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(5,5), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.05))

cnn.add(Conv2D(64, kernel_size=(5,5), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.5))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(len(categories), activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 128, 64)      51264
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_3 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 268,539,826
# Trainable params: 268,539,826
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 546/546 [==============================] - 48s 87ms/step - loss: 3.0351 - accuracy: 0.5825 - val_loss: 1.1442 - val_accuracy: 0.7993
# Epoch 2/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.6075 - accuracy: 0.8951 - val_loss: 0.9530 - val_accuracy: 0.8361
# Epoch 3/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.2790 - accuracy: 0.9651 - val_loss: 1.0934 - val_accuracy: 0.8428
# Epoch 4/10
# 546/546 [==============================] - 48s 87ms/step - loss: 0.2023 - accuracy: 0.9808 - val_loss: 1.4065 - val_accuracy: 0.8348
# Epoch 5/10
# 546/546 [==============================] - 47s 87ms/step - loss: 0.1949 - accuracy: 0.9785 - val_loss: 1.1848 - val_accuracy: 0.8428
# Epoch 6/10
# 546/546 [==============================] - 47s 87ms/step - loss: 0.1554 - accuracy: 0.9834 - val_loss: 1.2974 - val_accuracy: 0.8372
# Epoch 7/10
# 546/546 [==============================] - 47s 86ms/step - loss: 0.1573 - accuracy: 0.9812 - val_loss: 1.4159 - val_accuracy: 0.8324
# Epoch 8/10
# 546/546 [==============================] - 47s 86ms/step - loss: 0.1331 - accuracy: 0.9854 - val_loss: 1.2837 - val_accuracy: 0.8393
# Epoch 9/10
# 546/546 [==============================] - 47s 87ms/step - loss: 0.1178 - accuracy: 0.9854 - val_loss: 1.3283 - val_accuracy: 0.8432
# Epoch 10/10
# 546/546 [==============================] - 47s 86ms/step - loss: 0.0872 - accuracy: 0.9897 - val_loss: 1.3046 - val_accuracy: 0.8497
# Time elapsed: 474.0552694797516s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ## **1.8. MODEL 7**

# %%
cnn = Sequential()
cnn.add(Conv2D(32, kernel_size=(3,3), input_shape=X.shape[1:], padding='same', kernel_initializer='he_normal', activation='relu', kernel_constraint=unit_norm()))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Conv2D(64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(l=0.01)))
cnn.add(MaxPooling2D())
cnn.add(Dropout(0.4))

cnn.add(Flatten())
cnn.add(Dense(1024, activation='relu'))

cnn.add(Dense(len(categories), activation='softmax'))
cnn.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

print(cnn.summary())

import time
start = time.time()
history_cnn = cnn.fit(X_train, y_train, epochs=10, verbose=1, validation_data=(X_test, y_test))
end = time.time()
print('Time elapsed: {}s'.format(end-start))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 256, 256, 32)      320
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 128, 128, 32)      0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 128, 64)      18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 64, 64, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 262144)            0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              268436480
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                51250
# =================================================================
# Total params: 268,506,546
# Trainable params: 268,506,546
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 546/546 [==============================] - 45s 81ms/step - loss: 10.4384 - accuracy: 0.3887 - val_loss: 1.5829 - val_accuracy: 0.7291
# Epoch 2/10
# 546/546 [==============================] - 44s 80ms/step - loss: 1.0606 - accuracy: 0.8189 - val_loss: 1.2408 - val_accuracy: 0.7902
# Epoch 3/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.5850 - accuracy: 0.9166 - val_loss: 1.3132 - val_accuracy: 0.8094
# Epoch 4/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.4055 - accuracy: 0.9513 - val_loss: 1.3144 - val_accuracy: 0.8201
# Epoch 5/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.3078 - accuracy: 0.9705 - val_loss: 1.3772 - val_accuracy: 0.8250
# Epoch 6/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.2683 - accuracy: 0.9756 - val_loss: 1.3890 - val_accuracy: 0.8303
# Epoch 7/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.2237 - accuracy: 0.9813 - val_loss: 1.3541 - val_accuracy: 0.8282
# Epoch 8/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.2037 - accuracy: 0.9815 - val_loss: 1.3722 - val_accuracy: 0.8313
# Epoch 9/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.1795 - accuracy: 0.9821 - val_loss: 1.3731 - val_accuracy: 0.8341
# Epoch 10/10
# 546/546 [==============================] - 44s 80ms/step - loss: 0.1410 - accuracy: 0.9866 - val_loss: 1.3582 - val_accuracy: 0.8263
# Time elapsed: 439.7498471736908s

# %%
print_graphs(history_cnn)

# %% [markdown]
# ### Saving model 7

# %%
cnn.save('/content/gdrive/MyDrive/Colab Notebooks/automotive_runs/models/automotive_256_model.h5')
